# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('format.csv')
df['data'] = pd.to_datetime(df['data'], format='%d:%H:%M:%S')

# %%
df
# Out:
#                      data   valor
# 0     1900-01-01 08:27:16      23
# 1     1900-01-01 08:27:17      23
# 2     1900-01-01 08:27:18      23
# 3     1900-01-01 08:27:19      24
# 4     1900-01-01 08:27:20      24
# 5     1900-01-01 08:27:21      24
# 6     1900-01-01 08:27:22      23
# 7     1900-01-01 08:27:23      23
# 8     1900-01-01 08:27:24      23
# 9     1900-01-01 08:27:25      24
# 10    1900-01-01 08:27:26      24
# 11    1900-01-01 08:27:27      24
# 12    1900-01-01 08:27:28      24
# 13    1900-01-01 08:27:29      23
# 14    1900-01-01 08:27:30      23
# 15    1900-01-01 08:27:31      23
# 16    1900-01-01 08:27:32      23
# 17    1900-01-01 08:27:33      23
# 18    1900-01-01 08:27:34      23
# 19    1900-01-01 08:27:35      23
# 20    1900-01-01 08:27:36      23
# 21    1900-01-01 08:27:37      23
# 22    1900-01-01 08:27:38      24
# 23    1900-01-01 08:27:39      24
# 24    1900-01-01 08:27:40      24
# 25    1900-01-01 08:27:41      23
# ...

# %%
df[500:1000].plot(x='data')

# %%
df.describe()
# Out:
#               valor
# count  65535.000000
# mean      14.821530
# std        5.866914
# min        2.000000
# 25%       15.000000
# 50%       15.000000
# 75%       19.000000
# max       24.000000
